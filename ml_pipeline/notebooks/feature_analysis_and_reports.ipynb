# %%
# notebooks/feature_analysis_and_reports.py
import os
import joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import shap

# %%
# ---------- Config / paths ----------
ROOT = os.path.abspath(os.path.join(os.path.dirname(StudentPerformanceAnalysis), '..'))
DATA_DIR = os.path.join(ROOT, 'data', 'preprocessed')
MODEL_PATHS = [
    os.path.join(ROOT, 'dashboard', 'best_model.pkl'),
    os.path.join(ROOT, 'dashboard', 'best_model.joblib'),
    os.path.join(ROOT, 'dashboard', 'best_model.xgb'),
    os.path.join(ROOT, 'dashboard', 'best_model.json'),
]
OUTPUT_REPORT_CSV = os.path.join(DATA_DIR, 'student_reports.csv')
FEATURE_IMP_PNG = os.path.join(DATA_DIR, 'feature_importance.png')
MODEL_PERF_CSV = os.path.join(DATA_DIR, 'model_performance.csv')  # you already have this
# Out:
# ----------------------------------------------
# NameError    Traceback (most recent call last)
# Cell In[5], line 2
#       1 # ---------- Config / paths ----------
# ----> 2 ROOT = os.path.abspath(os.path.join(os.path.dirname(StudentPerformanceAnalysis), '..'))
#       3 DATA_DIR = os.path.join(ROOT, 'data', 'preprocessed')
#       4 MODEL_PATHS = [
#       5     os.path.join(ROOT, 'dashboard', 'best_model.pkl'),
#       6     os.path.join(ROOT, 'dashboard', 'best_model.joblib'),
#       7     os.path.join(ROOT, 'dashboard', 'best_model.xgb'),
#       8     os.path.join(ROOT, 'dashboard', 'best_model.json'),
#       9 ]
#
# NameError: name 'StudentPerformanceAnalysis' is not defined
